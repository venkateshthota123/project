# %% [markdown]
# <a href="https://colab.research.google.com/github/venkateshthota123/project/blob/main/data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data={
    "name":["venky","raju","siva"],
    "age":[22,21,23],
    "graduation":["b.tech","b.tech",'degree']
}
data
# Out:
# {'name': ['venky', 'raju', 'siva'],
#  'age': [22, 21, 23],
#  'graduation': ['b.tech', 'b.tech', 'degree']}

# %% [markdown]
# # New Section

# %%
df=pd.DataFrame(data)
df
# Out:
#     name  age graduation
# 0  venky   22     b.tech
# 1   raju   21     b.tech
# 2   siva   23     degree

# %%
data_file=pd.read_csv("data_statistics.csv")
data_file.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data_file.tail(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8513                Meat   99.9042            OUT035
# 8514              Canned   57.5904            OUT045
# 8515        Baking Goods  157.5288            OUT018
# 8516              Others   58.7588            OUT018
# 8517        Frozen Foods  178.8318            OUT046
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8513                       2004       Small               Tier 2
# 8514                       2002         NaN               Tier 2
# 8515                       2009      Medium               Tier 3
# 8516                       2009      Medium               Tier 3
# 8517                       1997       Small               Tier 1
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 8513  Supermarket Type1           595.2252
# 8514  Supermarket Type1           468.7232
# 8515  Supermarket Type2          1571.2880
# 8516  Supermarket Type2           858.8820
# 8517  Supermarket Type1          3608.6360
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700

# %%
print(data_file['Item_Fat_Content'])

print(data_file[['Item_MRP','Item_Type']])
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 8523, dtype: object
#       Item_MRP              Item_Type
# 0     249.8092                  Dairy
# 1      48.2692            Soft Drinks
# 2     141.6180                   Meat
# 3     182.0950  Fruits and Vegetables
# 4      53.8614              Household
# ...        ...                    ...
# 8518  214.5218            Snack Foods
# 8519  108.1570           Baking Goods
# 8520   85.1224     Health and Hygiene
# 8521  103.1332            Snack Foods
# 8522   75.4670            Soft Drinks
#
# [8523 rows x 2 columns]

# %%
print(data_file.dropna())
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# ...                  ...       ...               ...
# 8517        Frozen Foods  178.8318            OUT046
# 8518         Snack Foods  214.5218            OUT013
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 4                          1987        High               Tier 3
# 5                          2009      Medium               Tier 3
# ...                         ...         ...                  ...
# 8517                       1997       Small               Tier 1
# 8518                       1987        High               Tier 3
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 4     Supermarket Type1           994.7052
# 5     Supermarket Type2           556.6088
# ...                 ...                ...
# 8517  Supermarket Type1          3608.6360
# 8518  Supermarket Type1          2778.3834
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [4650 rows x 12 columns]

# %%
data_file.iloc[[0,1]]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %%
print(data_file[data_file['Outlet_Establishment_Year']>2000])
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 5              FDP36       10.395          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 16             NCB42       11.800          Low Fat         0.008596
# ...              ...          ...              ...              ...
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1            Soft Drinks   48.2692            OUT018
# 5           Baking Goods   51.4008            OUT018
# 8           Frozen Foods   96.9726            OUT045
# 9           Frozen Foods  187.8214            OUT017
# 16    Health and Hygiene  115.3492            OUT018
# ...                  ...       ...               ...
# 8515        Baking Goods  157.5288            OUT018
# 8516              Others   58.7588            OUT018
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1                          2009      Medium               Tier 3
# 5                          2009      Medium               Tier 3
# 8                          2002         NaN               Tier 2
# 9                          2007         NaN               Tier 2
# 16                         2009      Medium               Tier 3
# ...                         ...         ...                  ...
# 8515                       2009      Medium               Tier 3
# 8516                       2009      Medium               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 1     Supermarket Type2           443.4228
# 5     Supermarket Type2           556.6088
# 8     Supermarket Type1          1076.5986
# 9     Supermarket Type1          4710.5350
# 16    Supermarket Type2          1621.8888
# ...                 ...                ...
# 8515  Supermarket Type2          1571.2880
# 8516  Supermarket Type2           858.8820
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
#
# [3713 rows x 12 columns]

# %%
import pandas as pd
import string
import random

def generate_random_name():
    first_names = ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace", "Hank", "Ivy", "Jack"]
    last_names = ["Smith", "Johnson", "Williams", "Jones", "Brown", "Davis", "Miller", "Wilson", "Moore", "Taylor"]
    return f"{random.choice(first_names)} {random.choice(last_names)}"

# Generate random data for 100 students
data = {
    'student_name': [generate_random_name() for _ in range(100)],
    'student_marks': [random.randint(50, 100) for _ in range(100)],
    'student_id': ["".join(random.choices(string.ascii_uppercase + string.digits, k=8)) for _ in range(100)]
}

# %%
data_frame=pd.DataFrame(data)
data_frame.head()
# Out:
#    student_name  student_marks student_id
# 0    Eva Wilson             67   Y21FTRMF
# 1     Bob Davis             73   VCZ8A2VV
# 2    Ivy Taylor             99   W3DPENFK
# 3  Grace Miller             66   A4VHE3Y2
# 4  Alice Wilson             53   9DHHFEK6

# %% [markdown]
# print(data_frame[data_frame['student_marks']>70])

# %%
print(data_frame['student_marks'].mean())
print(data_frame['student_marks'].min())
print(data_frame['student_marks'].max())
print(data_frame['student_marks'].median())
print(data_frame['student_marks'].mode())
# Out:
# 75.7
# 50
# 100
# 75.0
# 0    60
# Name: student_marks, dtype: int64

# %%
print(data_frame['student_marks'].describe())
# Out:
# count    100.000000
# mean      75.700000
# std       15.024895
# min       50.000000
# 25%       62.750000
# 50%       75.000000
# 75%       88.250000
# max      100.000000
# Name: student_marks, dtype: float64

# %%
data_frame.describe()
# Out:
#        student_marks
# count     100.000000
# mean       75.700000
# std        15.024895
# min        50.000000
# 25%        62.750000
# 50%        75.000000
# 75%        88.250000
# max       100.000000

# %%
data=data_frame.head(10)
data
# Out:
#        student_name  student_marks student_id
# 0        Eva Wilson             67   Y21FTRMF
# 1         Bob Davis             73   VCZ8A2VV
# 2        Ivy Taylor             99   W3DPENFK
# 3      Grace Miller             66   A4VHE3Y2
# 4      Alice Wilson             53   9DHHFEK6
# 5         Eva Brown             60   EBE35351
# 6       David Jones             80   MSORMP8C
# 7  Charlie Williams             88   GR3V1E23
# 8         Ivy Davis             64   4AX6241E
# 9      Jack Johnson             95   KIHVG6MO

# %%
data.nlargest(10,'student_marks')
# Out:
#        student_name  student_marks student_id
# 2        Ivy Taylor             99   W3DPENFK
# 9      Jack Johnson             95   KIHVG6MO
# 7  Charlie Williams             88   GR3V1E23
# 6       David Jones             80   MSORMP8C
# 1         Bob Davis             73   VCZ8A2VV
# 0        Eva Wilson             67   Y21FTRMF
# 3      Grace Miller             66   A4VHE3Y2
# 8         Ivy Davis             64   4AX6241E
# 5         Eva Brown             60   EBE35351
# 4      Alice Wilson             53   9DHHFEK6

# %%
data_frame[data_frame['student_marks']>50].nlargest(3,'student_marks')
# Out:
#      student_name  student_marks student_id
# 42  David Johnson            100   8VW63FRS
# 2      Ivy Taylor             99   W3DPENFK
# 49      Ivy Moore             99   ETNH6D1E

# %%
df=data_frame[data_frame['student_marks']>50].sort_values(by=['student_marks','student_name'])
df
# Out:
#      student_name  student_marks student_id
# 30    Alice Moore             51   NTEB72GM
# 14    Frank Jones             52   ZLINSFHV
# 4    Alice Wilson             53   9DHHFEK6
# 34    Jack Taylor             53   23DU9ST3
# 90   Alice Taylor             54   OMYRQK9K
# ..            ...            ...        ...
# 80   Alice Taylor             99   HQPPPG47
# 55     Eva Miller             99   RNPSXYFF
# 49      Ivy Moore             99   ETNH6D1E
# 2      Ivy Taylor             99   W3DPENFK
# 42  David Johnson            100   8VW63FRS
#
# [96 rows x 3 columns]

# %%
def highest_marks(student_marks):
  if student_marks>=75:
    return 'A'
  elif student_marks>=65:
    return 'B'
  elif student_marks>=45:
    return 'C'
  elif student_marks>=30:
    return 'D'
  else:
    return 'F'

# %%
data_frame['Grades']=data_frame['student_marks'].map(highest_marks)
data_frame
# Out:
#       student_name  student_marks student_id Grades
# 0       Eva Wilson             67   Y21FTRMF      B
# 1        Bob Davis             73   VCZ8A2VV      B
# 2       Ivy Taylor             99   W3DPENFK      A
# 3     Grace Miller             66   A4VHE3Y2      B
# 4     Alice Wilson             53   9DHHFEK6      C
# ..             ...            ...        ...    ...
# 95  Frank Williams             92   QR4U8QG7      A
# 96     Alice Davis             56   N8ZBUT59      C
# 97     Alice Jones             60   ZVGZI398      C
# 98     Eva Johnson             60   NJVGJ9FL      C
# 99     Grace Davis             82   TDHJHL9R      A
#
# [100 rows x 4 columns]

# %%
data_frame[data_frame['Grades']=='A']
# Out:
#         student_name  student_marks student_id Grades
# 2         Ivy Taylor             99   W3DPENFK      A
# 6        David Jones             80   MSORMP8C      A
# 7   Charlie Williams             88   GR3V1E23      A
# 9       Jack Johnson             95   KIHVG6MO      A
# 10     David Johnson             81   QBAKJ98F      A
# 13     Frank Johnson             77   HBW1CVOD      A
# 15    Frank Williams             95   G01DI8OQ      A
# 16         Ivy Moore             84   BH9N1ZPW      A
# 20        Eva Taylor             98   ULQG77K3      A
# 21        Hank Smith             98   A0OAG00Z      A
# 23        Bob Miller             92   8IL2X4L6      A
# 24      Eva Williams             86   4CJBSGGM      A
# 28         Eva Smith             94   7MUF8UZM      A
# 31    Frank Williams             75   PVI3NM1H      A
# 32      David Taylor             75   TR687OHA      A
# 33       Grace Davis             87   MYWU61LX      A
# 35       Alice Smith             91   UPWJKNAJ      A
# 36        Ivy Taylor             94   WVWQ3CIN      A
# 37       Grace Brown             88   J48Q6TLO      A
# 38         Bob Davis             92   7QP9DZEX      A
# 41       Grace Moore             78   8E3PW01O      A
# 42     David Johnson            100   8VW63FRS      A
# 45     David Johnson             95   BL39NSIQ      A
# 46    Charlie Taylor             96   3JGTKESU      A
# 49         Ivy Moore             99   ETNH6D1E      A
# 50    Charlie Taylor             87   OZOE2UXF      A
# 51       Alice Smith             89   O89R2C2D      A
# 53        Hank Jones             86   MYID77VM      A
# 55        Eva Miller             99   RNPSXYFF      A
# 56        Bob Miller             88   06MI7E0E      A
# 60       Grace Davis             90   SH4BB471      A
# 62       Alice Jones             77   SYZDYF4A      A
# 65     Charlie Brown             85   EXIAUKDT      A
# 66       Jack Wilson             87   KU0A8G4T      A
# 67    Frank Williams             94   GN9818GT      A
# 69        Hank Davis             88   5TAG5KBG      A
# 71       Frank Smith             95   ENXB6YDM      A
# 72        Hank Moore             97   Y3FNT6MF      A
# 74      David Wilson             89   QBKBK3GA      A
# 75         Ivy Smith             86   NE7DX371      A
# 77       David Moore             80   MBD9VSW3      A
# 80      Alice Taylor             99   HQPPPG47      A
# 82      Alice Wilson             88   0Z0OLW2O      A
# 85         Eva Brown             89   C8RZNFUT      A
# 86     Charlie Davis             79   J5PJC1MG      A
# 88       Alice Smith             90   2BZP43D3      A
# 91     Charlie Smith             77   5KFXH8E5      A
# 92  Charlie Williams             82   GNTE4PZZ      A
# 94         Ivy Smith             88   V75P4WNX      A
# 95    Frank Williams             92   QR4U8QG7      A
# 99       Grace Davis             82   TDHJHL9R      A

# %%
data_frame[data_frame['Grades']=='A']['student_name']
# Out:
# 2           Ivy Taylor
# 6          David Jones
# 7     Charlie Williams
# 9         Jack Johnson
# 10       David Johnson
# 13       Frank Johnson
# 15      Frank Williams
# 16           Ivy Moore
# 20          Eva Taylor
# 21          Hank Smith
# 23          Bob Miller
# 24        Eva Williams
# 28           Eva Smith
# 31      Frank Williams
# 32        David Taylor
# 33         Grace Davis
# 35         Alice Smith
# 36          Ivy Taylor
# 37         Grace Brown
# 38           Bob Davis
# 41         Grace Moore
# 42       David Johnson
# 45       David Johnson
# 46      Charlie Taylor
# 49           Ivy Moore
# 50      Charlie Taylor
# 51         Alice Smith
# 53          Hank Jones
# 55          Eva Miller
# 56          Bob Miller
# 60         Grace Davis
# 62         Alice Jones
# 65       Charlie Brown
# 66         Jack Wilson
# 67      Frank Williams
# 69          Hank Davis
# 71         Frank Smith
# 72          Hank Moore
# 74        David Wilson
# 75           Ivy Smith
# 77         David Moore
# 80        Alice Taylor
# 82        Alice Wilson
# 85           Eva Brown
# 86       Charlie Davis
# 88         Alice Smith
# 91       Charlie Smith
# 92    Charlie Williams
# 94           Ivy Smith
# 95      Frank Williams
# 99         Grace Davis
# Name: student_name, dtype: object

# %%
df.sort_values(by=['student_name'])
# Out:
#      student_name  student_marks student_id
# 96    Alice Davis             56   N8ZBUT59
# 58  Alice Johnson             65   04OFXDD0
# 11  Alice Johnson             57   3Z4NI1UA
# 62    Alice Jones             77   SYZDYF4A
# 97    Alice Jones             60   ZVGZI398
# ..            ...            ...        ...
# 9    Jack Johnson             95   KIHVG6MO
# 87     Jack Jones             72   QXUC4FPO
# 34    Jack Taylor             53   23DU9ST3
# 76    Jack Wilson             74   CORSEQ31
# 66    Jack Wilson             87   KU0A8G4T
#
# [96 rows x 3 columns]
